# %% [markdown]
# # Home task
#
# ### Find the public dataset and apply collaborative filtering recommendation

# %%
import collaborative_filtering as cofi
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("ml-latest-small/ratings.csv")

df.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
userId = 'userId'
movieId = 'movieId'
rating = 'rating'

df_pred, J_hist = cofi.fill_missed(df[[userId, movieId, rating]], compute_average_for_blank_columns=False, n_features=20, max_iter=5000, return_J_hist=True)
# Out:
# index: userId, columns: movieId, values: rating
# c:\camp_homeworks\home_work_17_cofi\collaborative_filtering.py:145: FutureWarning: The provided callable <function max at 0x000001FCE8E12340> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_target=df.pivot_table(index=index, columns=columns, values=values, aggfunc=np.max, dropna= False)
# c:\camp_homeworks\home_work_17_cofi\collaborative_filtering.py:151: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   R= df_target.applymap(lambda x: 0 if np.isnan(x) else 1)
# Running gradient descent with alpha= 0.0005, lambda= 1, eps= 0.01, max_iter= 5000
# 50: 262883.6784591304
# 100: 239717.81966797134
# 150: 222597.935594672
# 200: 207678.23975705096
# 250: 194358.28402062878
# 300: 182190.83958379377
# 350: 170930.5348913857
# 400: 160455.54752411583
# 450: 150707.52520350725
# ...

# %%
df_pred
# Out:
#          userId  movieId  rating  rating_pred_round  rating_pred
# 0             1        1     4.0                4.5     4.402879
# 1             2        1     NaN                4.0     4.054466
# 2             3        1     NaN                1.0     0.750794
# 3             4        1     NaN                4.0     3.926467
# 4             5        1     4.0                4.5     4.373660
# ...         ...      ...     ...                ...          ...
# 5931635     606   193609     NaN                3.5     3.709528
# 5931636     607   193609     NaN                3.0     3.196633
# 5931637     608   193609     NaN                3.0     2.836879
# 5931638     609   193609     NaN                3.0     3.041320
# 5931639     610   193609     NaN                4.0     3.776756
#
# [5931640 rows x 5 columns]

# %%
df_pred[df_pred['rating'].notna()]
# Out:
#          userId  movieId  rating  rating_pred_round  rating_pred
# 0             1        1     4.0                4.5     4.402879
# 4             5        1     4.0                4.5     4.373660
# 6             7        1     4.5                4.5     4.462963
# 14           15        1     2.5                3.5     3.338066
# 16           17        1     4.5                4.0     4.154603
# ...         ...      ...     ...                ...          ...
# 5928773     184   193581     4.0                4.0     3.974130
# 5929383     184   193583     3.5                3.5     3.475954
# 5929993     184   193585     3.5                3.5     3.477831
# 5930603     184   193587     3.5                3.5     3.476779
# 5931360     331   193609     4.0                4.0     3.948350
#
# [100836 rows x 5 columns]
